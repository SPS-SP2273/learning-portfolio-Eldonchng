# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Using Jupyter (Good), Exercises</span></div>

# %%
while True:
    print('*', end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************
# ...

# %%
print = 'PRINT'

# %%
print('Hello World')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print('Hello World')
#
# TypeError: 'str' object is not callable

# %%
squares = [i**2 for i in range(10)]
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares = list()
for i in range(10):
    squares.append(i**2)
print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
# %%timeit
squares = [i**2 for i in range(10)]
print(squares) #Running this code will cause a contiunous loop creating a larger number of output. This occurs as %%timeit will run the code below it in  a loop around 700000 times causing 700000 lines of code of print(square) to be outputed

# %%
# %%timeit
for i in range(10):
    squares.append(i**2)
print(squares)

# %%
# %%timeit
squares = [i**2 for i in range(10)]
# Out:
# 1.64 μs ± 134 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit
squares = list()
for i in range(10):
    squares.append(i**2) 
    # When we are using %%timeit, we cant use print(square) and vice versa
    #The output shows both the mean and the s.d time taken for the code below it to run. %%timeit also causes the code to run 7 times with 100000 loops each totaling 700000 loops
    #From both output shown, the code above is easier to process due to its lower mean time compared to the code below.
# Out:
# 1.81 μs ± 465 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
