# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os
import glob
import shutil


dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

x = 'oct-08_singapore.txt'
date, location = x.split("_")
month, year =date.split("-")
month_no = dict[month]
new_file = f"{month_no}-{year}_{location}"
print(new_file)
# Out:
# 10-08_singapore.txt

# %%
dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
def rename_my_file(old_file_name):
    x = old_file_name
    date, location = x.split("_")
    month, year =date.split("-")
    month_no = dict[month]
    new_file = f"{month_no}-{year}_{location}"
    return new_file

rename_my_file('oct-08_singapore.txt')
# Out:
# '10-08_singapore.txt'

# %%
import os 
dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}
text_file =['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for file in text_file:
    new_file = rename_my_file(file)
    print(new_file)
    
#creates new files from text_file in Task 4
#for file in txt_file:
 #   pathing1 = os.path.join(filing_path,file)
  #  with open(pathing1, 'w') as f: #open(...) creates the files
   #     pass #creats an empty file

#for i in txt_file:
 #   file = os.path.basename(i)
  #  new_file_name = rename_my_file(i)
  #  old_path = os.path.join(filing_path,i) #This is necessary as we are doing a loop.
   # new_path = os.path.join(filing_path,new_file_name)
    # new_file= os.rename(old_path,new_path)
# Out:
# 10-08_singapore.txt
# 07-10_cairo.txt
# 05-15_dhaka.txt
# 05-13_cairo.txt
# 10-21_cairo.txt
# 01-10_singapore.txt
# 06-20_tokyo.txt
# 08-06_jakarta.txt
# 12-21_karachi.txt
# 01-01_tokyo.txt

# %%
import glob
#glob.glob('C:/Users/user/Documents/GitHub/learning-portfolio-Eldonchng/6.2_files,_folders_&_os__exercises/os-collaboration-exercise-data/*.txt')
#glob.glob('C:/Users/user/Documents/os-collaboration-exercise-data/*.txt')
glob.glob("C:/Users/user/Documents/os-collaboration-exercise-data.zip/*.txt")
#glob.glob can not be used for zip files as the two codes (comments) works but not the last code!
# Out:
# []

# %%
import glob
import os

dict = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}



#txt_file= glob.glob('**.txt')
txt_file= glob.glob('C:/Users/user/Documents/GitHub/learning-portfolio-Eldonchng/6.2_files,_folders_&_os__exercises/os-collaboration-exercise-data/*.txt')
#for i in txt_file:
    #folder_path = os.path.basename(i) #.basename returns the file name or the final destination of the path
    #all_text.append(folder_path)

#for file_path in all_text:
  # new_pathrename_my_file(file_path)
filing_path = r"C:\Users\user\Documents\GitHub\learning-portfolio-Eldonchng\6.2_files,_folders_&_os__exercises\Task 4"
#creates new files from text_file in Task 4
#for file in txt_file:
 #   pathing1 = os.path.join(filing_path,file)
  #  with open(pathing1, 'w') as f: #open(...) creates the files
   #     pass #creats an empty file

for i in txt_file:
    file = os.path.basename(i)
    new_file_name = rename_my_file(file)
    new_path = os.path.join(filing_path,new_file_name)
    new_file = os.rename(i,new_path)

for item in glob.glob("**", recursive=True):
    print(item)
# Out:
# (ready for review)files,_folders_&_os_(need)_exercises.ipynb
# cities
# cities\Cairo
# cities\Dhaka
# cities\Dhaka\apr-19_dhaka.png
# cities\Dhaka\apr-20_dhaka.png
# cities\Dhaka\apr-23_dhaka.pdf
# cities\Dhaka\aug-02_dhaka.jpg
# cities\Dhaka\aug-03_dhaka.jpg
# cities\Dhaka\aug-03_dhaka.png
# cities\Dhaka\aug-05_dhaka.png
# cities\Dhaka\aug-06_dhaka.pdf
# cities\Dhaka\aug-08_dhaka.pdf
# cities\Dhaka\aug-09_dhaka.pdf
# cities\Dhaka\aug-10_dhaka.jpg
# cities\Dhaka\aug-10_dhaka.pdf
# cities\Dhaka\aug-11_dhaka.pdf
# cities\Dhaka\aug-14_dhaka.pdf
# cities\Dhaka\aug-18_dhaka.png
# cities\Dhaka\aug-19_dhaka.jpg
# cities\Dhaka\aug-20_dhaka.pdf
# cities\Dhaka\aug-22_dhaka.png
# cities\Dhaka\aug-23_dhaka.pdf
# cities\Dhaka\aug-25_dhaka.jpg
# cities\Dhaka\aug-26_dhaka.jpg
# cities\Dhaka\aug-27_dhaka.png
# cities\Dhaka\aug-30_dhaka.pdf
# cities\Dhaka\dec-02_dhaka.png
# cities\Dhaka\dec-03_dhaka.pdf
# cities\Dhaka\dec-04_dhaka.pdf
# cities\Dhaka\dec-06_dhaka.jpg
# cities\Dhaka\dec-09_dhaka.jpg
# ...

# %%
list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
try:
    os.mkdir("cities") #folder cities is made in 6.2..... as this folder will be in the folder we are working on here in vscode which is the 6.2_files_folder.....
    for city in list:
        path = os.path.join("cities",city)
        os.mkdir(path)

except FileExistsError:
    print("This folder and files already exist!")
# Out:
# This folder and files already exist!

# %%
import shutil
txt_file= glob.glob('C:/Users/user/Documents/GitHub/learning-portfolio-Eldonchng/6.2_files,_folders_&_os__exercises/os-collaboration-exercise-data/*cairo.**')
#*cario/** is not correct! 

for i in txt_file:
    shutil.copy(i,"C:/Users/user/Documents/GitHub/learning-portfolio-Eldonchng/6.2_files,_folders_&_os__exercises/cities/Cairo")

# %%
import glob
import shutil
list = [ 'dhaka', 'jakarta', 'karachi', 'manila',
 'melbourne', 'osaka', 'shanghai', 'singapore', 'tokyo']
for i in list:
    txt_file= glob.glob(f'C:/Users/user/Documents/GitHub/learning-portfolio-Eldonchng/6.2_files,_folders_&_os__exercises/os-collaboration-exercise-data/*{i}.**')
    country_folder = (f"C:/Users/user/Documents/GitHub/learning-portfolio-Eldonchng/6.2_files,_folders_&_os__exercises/cities/{i}")

    for filing in txt_file:
        shutil.copy(filing,country_folder)
